# %%
# Import required python libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# Load data from csv file
data = pd.read_csv("company_data.csv", delimiter=",")
data.shape
# Out:
# (7051, 32)

# %%
# shows 1st 5 rows
data.head()
# Out:
#    Unnamed: 0 brand                phone     Status  release_year  \
# 0           1  Acer        Iconia A1-830  Available        2014.0
# 1           2  Acer        Iconia B1-720  Available        2014.0
# 2           3  Acer        Iconia B1-721  Available        2014.0
# 3           4  Acer  Iconia One 7 B1-730  Available        2014.0
# 4           5  Acer  Iconia Tab 7 A1-713  Available        2014.0
#
#   release_quarter headphone_jacks composer  MP3 monophonic    ...     \
# 0              Q1             Yes       No  Yes         No    ...
# 1              Q1             Yes       No  Yes         No    ...
# 2              Q1             Yes       No  Yes         No    ...
# 3              Q2             Yes       No  Yes         No    ...
# 4              Q3             Yes       No  Yes         No    ...
#
#   Push_Email Thread Radio Resolution Screen_size talk_time weight_in_g  \
# 0        Yes     No    No        212         7.9     450.0       380.0
# 1        Yes     No    No        188         7.0     300.0       315.0
# 2        Yes     No    No        188         7.0       0.0       323.0
# 3        Yes     No    No        770         7.0     420.0         0.0
# 4        Yes    Yes    No        188         7.0     360.0       298.0
#
#   Keyboard Primary Secondary
# 0     None     5.0       2.0
# 1     None     0.3       0.0
# 2     None     0.3       0.0
# 3     None     5.0       0.0
# 4     None     2.0       0.0
#
# [5 rows x 32 columns]

# %%
# days stores the no.of days the product has been in the inventory
days = np.random.random_integers(20, high=150, size=(data.shape[0],))
days
# Out:
# C:\Users\SEVA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: This function is deprecated. Please call randint(20, 150 + 1) instead
#   """Entry point for launching an IPython kernel.
# array([101,  82, 127, ...,  69,  70, 111])

# %%
# Filling null values with the mean values of the column
data.iloc[:,-7].fillna(data.iloc[:,-7].mean(), inplace=True)

# %%
data.iloc[:,-6].fillna(data.iloc[:,-6].mean(), inplace=True)
data.iloc[:,-5].fillna(data.iloc[:,-5].mean(), inplace=True)
data.iloc[:,-4].fillna(data.iloc[:,-4].mean(), inplace=True)
data.iloc[:,-2].fillna(data.iloc[:,-2].mean(), inplace=True)
data.iloc[:,-1].fillna(data.iloc[:,-1].mean(), inplace=True)

# %%
# Filling null values of string columns with the mode of the column
data = data.apply(lambda x:x.fillna(x.value_counts().index[0]))

# %%
# adding the target column to the end
data['status'] = data['Status']
data = data.drop(['Status'],axis=1)
data.shape
# Out:
# (7051, 32)

# %%
# Dropping less significant columns
data.drop('Keyboard', axis=1, inplace=True)
data.drop('phone', axis=1, inplace=True)
data.drop('release_year', axis=1, inplace=True)
data.drop('release_quarter', axis=1, inplace=True)

# %%
# Label encoding of categorical data to numerical data
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in ([1,11,-1]):
    array = le.fit_transform(np.array(data.iloc[:,i]))
    data.iloc[:,i] = array
data.head()
# Out:
#    Unnamed: 0  brand headphone_jacks composer  MP3 monophonic polyphonic  wav  \
# 0           1      1             Yes       No  Yes         No         No  Yes
# 1           2      1             Yes       No  Yes         No         No  Yes
# 2           3      1             Yes       No  Yes         No         No  Yes
# 3           4      1             Yes       No  Yes         No         No  Yes
# 4           5      1             Yes       No  Yes         No         No  Yes
#
#   vibration acc  ...   Push_Email  Thread Radio Resolution Screen_size  \
# 0       Yes  No  ...          Yes      No    No        212         7.9
# 1       Yes  No  ...          Yes      No    No        188         7.0
# 2       Yes  No  ...          Yes      No    No        188         7.0
# 3       Yes  No  ...          Yes      No    No        770         7.0
# 4       Yes  No  ...          Yes     Yes    No        188         7.0
#
#   talk_time weight_in_g Primary Secondary status
# 0     450.0       380.0     5.0       2.0      0
# 1     300.0       315.0     0.3       0.0      0
# 2       0.0       323.0     0.3       0.0      0
# 3     420.0         0.0     5.0       0.0      0
# 4     360.0       298.0     2.0       0.0      0
#
# [5 rows x 28 columns]

# %%
# Mapping 'Yes' category as 1 and 'No' category as 0
dict_= {'Yes': 1, 'No': 0}
for i in range(2, 10):
    data.iloc[:, i] = data.iloc[:, i].map(dict_)
for i in range(12, 21):
    data.iloc[:, i] = data.iloc[:, i].map(dict_)
data.head()
# Out:
#    Unnamed: 0  brand  headphone_jacks  composer  MP3  monophonic  polyphonic  \
# 0           1      1                1         0    1           0           0
# 1           2      1                1         0    1           0           0
# 2           3      1                1         0    1           0           0
# 3           4      1                1         0    1           0           0
# 4           5      1                1         0    1           0           0
#
#    wav  vibration  acc   ...   Push_Email  Thread  Radio  Resolution  \
# 0    1          1    0   ...            1       0      0         212
# 1    1          1    0   ...            1       0      0         188
# 2    1          1    0   ...            1       0      0         188
# 3    1          1    0   ...            1       0      0         770
# 4    1          1    0   ...            1       1      0         188
#
#    Screen_size  talk_time  weight_in_g  Primary  Secondary  status
# 0          7.9      450.0        380.0      5.0        2.0       0
# 1          7.0      300.0        315.0      0.3        0.0       0
# 2          7.0        0.0        323.0      0.3        0.0       0
# 3          7.0      420.0          0.0      5.0        0.0       0
# 4          7.0      360.0        298.0      2.0        0.0       0
#
# [5 rows x 28 columns]

# %%
# Mapping 'Yes' category as 1 and 'No' category as 0
data.bluetooth = data.bluetooth.map({'yes': 1, 'no': 0})

# %%
# Adding no.of days column to the data
data['no_of_days'] = days
data.head()
# Out:
#    Unnamed: 0  brand  headphone_jacks  composer  MP3  monophonic  polyphonic  \
# 0           1      1                1         0    1           0           0
# 1           2      1                1         0    1           0           0
# 2           3      1                1         0    1           0           0
# 3           4      1                1         0    1           0           0
# 4           5      1                1         0    1           0           0
#
#    wav  vibration  acc     ...      Thread  Radio  Resolution  Screen_size  \
# 0    1          1    0     ...           0      0         212          7.9
# 1    1          1    0     ...           0      0         188          7.0
# 2    1          1    0     ...           0      0         188          7.0
# 3    1          1    0     ...           0      0         770          7.0
# 4    1          1    0     ...           1      0         188          7.0
#
#    talk_time  weight_in_g  Primary  Secondary  status  no_of_days
# 0      450.0        380.0      5.0        2.0       0         101
# 1      300.0        315.0      0.3        0.0       0          82
# 2        0.0        323.0      0.3        0.0       0         127
# 3      420.0          0.0      5.0        0.0       0          45
# 4      360.0        298.0      2.0        0.0       0         129
#
# [5 rows x 29 columns]

# %%
# Testing data contains aged products whereas training data contains the rest
train_data = data[data.no_of_days < 90]
test_data = data[data.no_of_days >= 90]

# %%
# creating training and testing data to be trained and predicted respectively
X_train = train_data.iloc[:,:-2]
Y_train = train_data.iloc[:,-2]
X_test = test_data.iloc[:,:-2]
Y_test = test_data.iloc[:,-2]

# %%
X_train.shape
# Out:
# (3830, 27)

# %%
X_test.shape
# Out:
# (3221, 27)

# %%
# Normalizing the data to prevent overfitting
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
X_train
X_test
# Out:
# array([[-1.7451061 , -1.89762714,  0.9650995 , ...,  2.54206589,
#          0.51327952,  1.29275159],
#        [-1.74412451, -1.89762714,  0.9650995 , ...,  1.98027982,
#         -0.83451236, -0.36712256],
#        [-1.74314292, -1.89762714,  0.9650995 , ...,  1.73388242,
#         -0.34701317, -0.36712256],
#        ...,
#        [ 1.71206283,  1.76085641, -1.03616259, ..., -0.26686447,
#         -0.92054163, -0.36712256],
#        [ 1.71353521,  1.76085641, -1.03616259, ..., -0.37527932,
#         -0.54774813, -0.36712256],
#        [ 1.7150076 ,  1.76085641, -1.03616259, ..., -0.02046707,
#         -0.00289609, -0.36712256]])

# %%
# Using random forest classifier to predict probability of availability and discontinuity of products
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
clf1 = RandomForestClassifier(n_estimators=500, random_state=0)
clf1.fit(X_train, Y_train)
Y_pred = clf1.predict_proba(X_test)
clf1.score(X_test, Y_test)
# Out:
# 0.9379074821484011

# %%
# Storing the predictions into a csv file
prediction = pd.DataFrame(Y_pred, columns=['Available','Discontinued'])
prediction.to_csv('Predict1.csv')

# %%
# Using SVM classifier for prediction
from sklearn.svm import SVC
clf2 = SVC()
clf2.fit(X_train, Y_train)
Y_pred = clf1.predict(X_test)
clf2.score(X_test, Y_test)
# Out:
# 0.9226948152747594

# %%
# Using Neural networks for prediction
from sklearn.neural_network import MLPClassifier
clf3 = MLPClassifier(hidden_layer_sizes=(20,15), max_iter=3000)
clf3.fit(X_train, Y_train)
clf3.score(X_test, Y_test)
# Out:
# 0.9239366656317913

# %%
# We observed that random forest classifier predicted with highest accuracy
